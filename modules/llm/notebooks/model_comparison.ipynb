# %% [markdown]
# # Base vs LoRA comparison
#
# This notebook summarizes committed Ollama comparison results. Proxy outputs are excluded from model-quality claims.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().resolve()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent

RESULTS = ROOT / "results" / "model_comparison"
full = pd.read_csv(RESULTS / "ollama_20260614" / "final_model_comparison.csv")
citation_guard = pd.read_csv(
    RESULTS / "ollama_20260614_citation_guard_enforced" / "final_model_comparison.csv"
)
full

# %%
metrics = ["structure_compliance", "evidence_faithfulness", "citation_safety", "latency_seconds"]
full.groupby("model_variant")[metrics].mean().round(3)

# %%
citation_guard[[
    "prompt_id", "model_variant", "structure_compliance",
    "evidence_faithfulness", "citation_safety",
    "unsupported_source_ids", "latency_seconds", "error"
]]

# %% [markdown]
# ## How to read the results
#
# The review in `results/model_comparison/ollama_20260614/human_review.md` selects `qwen3:8b` as the production default. The adapter rows remain negative comparison evidence. The citation-guard table confirms the deterministic safety behavior for both model variants.
