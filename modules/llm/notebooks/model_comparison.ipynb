# %% [markdown]
# # Canonical Base vs LoRA Results
#
# This notebook is a lightweight executable view of the committed real Ollama evidence. Proxy outputs are intentionally excluded from model-quality claims.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().resolve()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent

RESULTS = ROOT / "results" / "model_comparison"
full = pd.read_csv(RESULTS / "ollama_20260614" / "final_model_comparison.csv")
citation_guard = pd.read_csv(
    RESULTS / "ollama_20260614_citation_guard_enforced" / "final_model_comparison.csv"
)
full

# %%
metrics = ["structure_compliance", "evidence_faithfulness", "citation_safety", "latency_seconds"]
full.groupby("model_variant")[metrics].mean().round(3)

# %%
citation_guard[[
    "prompt_id", "model_variant", "structure_compliance",
    "evidence_faithfulness", "citation_safety",
    "unsupported_source_ids", "latency_seconds", "error"
]]

# %% [markdown]
# ## Interpretation
#
# The human review in `results/model_comparison/ollama_20260614/human_review.md` selects `qwen3:8b` as the production default. The adapter remains negative comparison evidence. The citation-guard table verifies the accepted deterministic safety behavior for both model variants.
